# %% [markdown]
# # 📝 Exercise M1.01

# %% [markdown]
# Imagine we are interested in predicting penguins species based on two of
# their body measurements: culmen length and culmen depth. First we want to do
# some data exploration to get a feel for the data.
#
# What are the features? What is the target?

# %% [markdown]
# The data is located in `../datasets/penguins_classification.csv`, load it
# with `pandas` into a `DataFrame`.

# %%
import pandas as pd
penguin = pd.read_csv('../datasets/penguins_classification.csv')
print(penguin)
penguin['Species'].value_counts()
target = 'Species'
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)    Species
# 0                  39.1               18.7     Adelie
# 1                  39.5               17.4     Adelie
# 2                  40.3               18.0     Adelie
# 3                  36.7               19.3     Adelie
# 4                  39.3               20.6     Adelie
# ..                  ...                ...        ...
# 337                55.8               19.8  Chinstrap
# 338                43.5               18.1  Chinstrap
# 339                49.6               18.2  Chinstrap
# 340                50.8               19.0  Chinstrap
# 341                50.2               18.7  Chinstrap
#
# [342 rows x 3 columns]

# %% [markdown]
# Show a few samples of the data
#
# How many features are numerical? How many features are categorical?

# %%
numerical = ['Culmen Length (mm)', 'Culmen Depth (mm)']
categorical = []
target = ['Species']

print(penguin.shape)
print(penguin.head())

print()
print('{} features are numerical and {} features are categorical'.format(len(numerical), len(categorical)))
# Out:
# (342, 3)
#    Culmen Length (mm)  Culmen Depth (mm) Species
# 0                39.1               18.7  Adelie
# 1                39.5               17.4  Adelie
# 2                40.3               18.0  Adelie
# 3                36.7               19.3  Adelie
# 4                39.3               20.6  Adelie
#
# 2 features are numerical and 0 features are categorical

# %% [markdown]
# What are the different penguins species available in the dataset and how many
# samples of each species are there? Hint: select the right column and use
# the [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html) method.

# %%
penguin[target].value_counts()
# Out:
# Species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# dtype: int64

# %% [markdown]
# Plot histograms for the numerical features

# %%
_ = penguin.hist(numerical)

# %% [markdown]
# Show features distribution for each class. Hint: use
# [`seaborn.pairplot`](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
import seaborn as sns

print(penguin)
print(numerical)
print(target)
# penguin = penguin[numerical + target]
_ = sns.pairplot(data=penguin,hue=target[0], height=5)
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)    Species
# 0                  39.1               18.7     Adelie
# 1                  39.5               17.4     Adelie
# 2                  40.3               18.0     Adelie
# 3                  36.7               19.3     Adelie
# 4                  39.3               20.6     Adelie
# ..                  ...                ...        ...
# 337                55.8               19.8  Chinstrap
# 338                43.5               18.1  Chinstrap
# 339                49.6               18.2  Chinstrap
# 340                50.8               19.0  Chinstrap
# 341                50.2               18.7  Chinstrap
#
# [342 rows x 3 columns]
# ['Culmen Length (mm)', 'Culmen Depth (mm)']
# ['Species']

# %% [markdown]
# Looking at these distributions, how hard do you think it will be to classify
# the penguins only using "culmen depth" and "culmen length"?

# %% [markdown]
# il semblerait possible de classifier les différentes sortes de pingouin en prenant les axes Culmen Length = 42 pour l'Adelie et Culmen Depth = 16 pour le Gentoo

# %%
import matplotlib.pyplot as p

sns.scatterplot(data=penguin, x=numerical[0], y=numerical[1], hue=target[0])

culmen_length_threshold = 44
culmen_depth_threshold = 16

p.axvline(x=culmen_length_threshold, ymin=0.4, ymax=1, color="black", linestyle="--")
_ = plt.axhline(y=culmen_depth_threshold, xmin=0, xmax=1, color="black", linestyle="--")
